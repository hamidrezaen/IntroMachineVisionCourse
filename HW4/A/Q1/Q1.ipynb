# %% [markdown]
# ### Libraries

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the Image

# %%
### YOUR CODE ###
img = cv2.imread("q1.png", cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# ### Finding Threshold

# %%
# You can use cv2 methods for finding this
_, thresholded = cv2.threshold(img, 0, 255,
cv2.THRESH_BINARY | cv2.THRESH_OTSU)

# %%
# Show the results
plt.figure(figsize=(10,4))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Grayscale')

plt.subplot(1, 2, 2)
plt.imshow(thresholded, cmap='gray')
plt.title(f'Otsu Thresholding (Threshold = {_:.2f})')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Finding Connected Components

# %%
# You can use cv2 methods for finding them
### YOUR CODE ###
num_labels, labels_im = cv2.connectedComponents(img)

# %%
shape = [img.shape[0],img.shape[1], 3]
output = np.zeros(shape, dtype=np.uint8)

# %% [markdown]
# #### Show the result
#
# Show each component with a random color, and write the number of components on the result image

# %%
### YOUR CODE ###

for label in range(1, num_labels):
    color = np.random.randint(256, size=3)
    output[labels_im==label] = color

    
plt.imshow(output)
plt.show()

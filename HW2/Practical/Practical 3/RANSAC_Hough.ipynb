# %% [markdown]
# # RANSAC & Hough

# %% [markdown]
# ##### Kindly, please complete the missing parts. <p href='...'></p>

# %% [markdown]
# #

# %% [markdown]
# ## RANSAC

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Generate 50 inlier and 20 outlier points (line equation for inliers: 2x+1 with some normal noise added to it)

# %%
# Generate inlier points:
n_inliers = 50
x_inliers = # ...
y_inliers = # ...

# Generate outlier points:
n_outliers = 20
x_outliers = # ...
y_outliers = # ...

# Combine inliers and outliers:
x_data = # ...
y_data = # ...

# Shuffle the dataset:
indices = np.random.permutation(len(x_data))
x_data, y_data = x_data[indices], y_data[indices]

# %% [markdown]
# ### Plot the dataset

# %%
# Plot the dataset:
# YOUR CODE

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Dataset with Inliers and Outliers")
plt.show()

# %% [markdown]
# #### RANSAC algorithm

# %%
def ransac_line_fitting(x, y, num_iterations=100, threshold=2, min_inliers=30):
        
        ###############
        ## YOUR CODE ##
        ###############
            
    return best_model, best_inliers


# Nokte: best_model be form (m, b) mibashad va best_inliers yek ndarray az andis noghat inlier mibashad.

# %%
best_model, best_inliers = ransac_line_fitting(x_data, y_data)

if best_model:
    m_best, b_best = best_model
    print(f"Best Model: y = {m_best:.2f}x + {b_best:.2f}")
else:
    print("No valid model found.")
# Out:
# Best Model: y = 2.62x + 5.52

# %% [markdown]
# #

# %%
# Plot all points:
# YOUR CODE


# Plot inliers:
# YOUR CODE


# Plot best-fit line:
# YOUR CODEz

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("RANSAC Line Fitting")
plt.show()

# %% [markdown]
# #

# %% [markdown]
# ## Linear Hough

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import cv2
from scipy.ndimage import maximum_filter
import matplotlib.pyplot as plt

# %% [markdown]
# Initializing the accumulator

# %%
def initialize_accumulator(image_shape, theta_resolution=180):
    ###############
    ## YOUR CODE ##
    ###############
    return accumulator, rho_max

# %% [markdown]
# Finding the edge direction

# %%
def edge_direction(image_gradient_x, image_gradient_y):
    direction = # ...
    return direction

# %% [markdown]
# Using the Hough Transform pseudocode provided in the slides, implement the Hough Transform algorithm.

# %%
def hough_transform(edges, directions, threshold, theta_resolution=180):
    
    ###############
    ## YOUR CODE ##
    ###############
    
    return accumulator

# %%
def find_local_maxima(accumulator, threshold):
    
    ###############
    ## YOUR CODE ##
    ###############
    
    return maxima

# %%
def process_image(image_path, edge_threshold=50, hough_threshold=120):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    
    plt.figure(figsize=(6, 4))  
    plt.imshow(image, cmap='gray')
    plt.title('Original Image')
    plt.show()  
    
    edges = cv2.Canny(image, edge_threshold, edge_threshold * 2)
    plt.figure(figsize=(6, 4))  
    plt.imshow(edges, cmap='gray')
    plt.title('Edge Detection')
    plt.show() 
    
    gradient_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
    gradient_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
    directions = edge_direction(gradient_x, gradient_y)
    
    accumulator = hough_transform(edges, directions, threshold=0.5)
    plt.figure(figsize=(6, 4))  
    plt.imshow(accumulator, cmap='hot', aspect='auto')
    plt.title('Hough Accumulator')
    plt.show()  
    
    maxima = find_local_maxima(accumulator, hough_threshold)
    plt.figure(figsize=(6, 4))  
    plt.imshow(image, cmap='gray')
    
    for rho, theta in maxima:
        theta_rad = np.deg2rad(theta * (180 / accumulator.shape[1]))
        a = np.cos(theta_rad)
        b = np.sin(theta_rad)
        x0 = a * (rho - accumulator.shape[0] // 2)
        y0 = b * (rho - accumulator.shape[0] // 2)
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))
        plt.plot([x1, x2], [y1, y2], 'r')
    plt.title('Detected Lines')
    plt.show()  

img_path = ''
process_image(img_path)

# %% [markdown]
# ## Circle Hough

# %% [markdown]
# In this section, we have an image containing several circles. We want to identify the circular shapes in the image, calculate their areas, and determine which shapes contain holes. Complete the required parts to achieve the desired output.

# %% [markdown]
# Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def load_image(image_path):
    
    ###############
    ## YOUR CODE ##
    ###############
    
    return image

# %% [markdown]
# Smooth the image.

# %%
def preprocess_image(image):
    
    ###############
    ## YOUR CODE ##
    ###############
    
    return blur

# %% [markdown]
# Binarize the image

# %%
def apply_threshold(blur, threshold_value=128, max_value=255):
    
    ###############
    ## YOUR CODE ##
    ###############
    
    return thresh

# %% [markdown]
# Note: You can use the Library functions to apply the Hough transform.

# %%
def detect_circles(blur):

    ###############
    ## YOUR CODE ##
    ###############
    
    return circles

# %%
def process_circles(image, circles, blur, thresh):
    
    circles = np.round(circles[0, :]).astype("int")
    
    for i, (x, y, r) in enumerate(circles):
        cv2.circle(image, (x, y), r, (0, 255, 0), 2)
        cv2.putText(
            image, 
            str(i+1), 
            (x-r, y+4),
            cv2.FONT_HERSHEY_SIMPLEX, 
            0.8, 
            (0, 0, 255), 
            2
        )
        
        theoretical_area = math.pi * r * r
        
        circle_mask = np.zeros(blur.shape, dtype=np.uint8)
        cv2.circle(circle_mask, (x, y), r, 255, -1)
        circle_img = cv2.bitwise_and(thresh, circle_mask)
        actual_area = cv2.countNonZero(circle_img)
        
        if abs(theoretical_area - actual_area) > 220:
            print(f"Circle {i+1} with radius {r} \033[0;31;40mhas a hole\033[0m")
        
        print(f"Circle {i+1} with radius {r} has area {actual_area:.2f} (theoretical: {theoretical_area:.2f})")
    
    return image

# %%
def display_image(image, output_path='Image.JPG'):
   
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    plt.figure(figsize=(10, 8)) 
    plt.imshow(image_rgb)
    plt.axis('off')  
    plt.title('Processed Image')  
    plt.show()

# %%
def main():
    image_path = ""
    image = load_image(image_path)
    blur = preprocess_image(image)
    thresh = apply_threshold(blur)
    circles = detect_circles(blur)
    result_image = process_circles(image, circles, blur, thresh)
    display_image(result_image)

if __name__ == "__main__":
    main()
# Out:
# Circle 1 with radius 60 has area 11263.00 (theoretical: 11309.73)
# Circle 2 with radius 51 has area 8056.00 (theoretical: 8171.28)
# Circle 3 with radius 50 has a hole
# Circle 3 with radius 50 has area 7242.00 (theoretical: 7853.98)
# Circle 4 with radius 63 has area 12352.00 (theoretical: 12468.98)
# Circle 5 with radius 51 has area 8022.00 (theoretical: 8171.28)
# Circle 6 with radius 45 has area 6250.00 (theoretical: 6361.73)
# Circle 7 with radius 61 has area 11526.00 (theoretical: 11689.87)
# Circle 8 with radius 47 has area 6921.00 (theoretical: 6939.78)
# Circle 9 with radius 55 has area 9392.00 (theoretical: 9503.32)
# Circle 10 with radius 56 has a hole
# Circle 10 with radius 56 has area 9345.00 (theoretical: 9852.03)
# Circle 11 with radius 51 has area 8074.00 (theoretical: 8171.28)
# Circle 12 with radius 47 has a hole
# Circle 12 with radius 47 has area 6359.00 (theoretical: 6939.78)
# Circle 13 with radius 54 has a hole
# Circle 13 with radius 54 has area 8663.00 (theoretical: 9160.88)
# Circle 14 with radius 42 has area 5325.00 (theoretical: 5541.77)
# Circle 15 with radius 44 has area 6010.00 (theoretical: 6082.12)
# Circle 16 with radius 44 has a hole
# Circle 16 with radius 44 has area 5094.00 (theoretical: 6082.12)
# Circle 17 with radius 43 has a hole
# Circle 17 with radius 43 has area 5587.00 (theoretical: 5808.80)
# Circle 18 with radius 53 has area 8687.00 (theoretical: 8824.73)
# Circle 19 with radius 69 has area 14949.00 (theoretical: 14957.12)

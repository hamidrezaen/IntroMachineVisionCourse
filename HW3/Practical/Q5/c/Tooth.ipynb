# %% [markdown]
# # Import Libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Image

# %%
# Path to the image
image_path = ""  # Set your image path here         #TO DO

# %% [markdown]
# # a) Read the image in grayscale

# %%
image_gray =          #TO DO

# %% [markdown]
# # b) Apply pseudo-coloring using a suitable colormap

# %%
image_color =          #TO DO

# %% [markdown]
# # c) Display both grayscale and pseudo-colored images

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Original Grayscale X-ray")
plt.imshow(image_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("Pseudo-colored X-ray (COLORMAP_JET)")
plt.imshow(cv2.cvtColor(image_color, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.tight_layout()
plt.show()

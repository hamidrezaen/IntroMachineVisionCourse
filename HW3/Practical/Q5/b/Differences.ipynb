# %% [markdown]
# # Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load two grayscale images

# %%
img1 = cv2.imread('', cv2.IMREAD_GRAYSCALE)         #TO DO
img2 = cv2.imread('', cv2.IMREAD_GRAYSCALE)         #TO DO

# %%
# Make sure both images have the same size
if img1.shape != img2.shape:
         #TO DO

# %% [markdown]
# # Method 1

# %%
# Create an RGB image where:
# - Red channel is img1
# - Green channel is img2
# - Blue channel is zeros
blue_channel =              #TO DO

# %%
# Stack the channels
color_diff =   # (B, G, R)         #TO DO

# %%
# Convert to RGB for displaying with matplotlib (OpenCV uses BGR)
color_diff_rgb =          #TO DO

# %%
# Show the result
plt.imshow(color_diff_rgb)
plt.title('Difference Highlighted in Color')
plt.axis('off')
plt.show()

# %% [markdown]
# # Method 2

# %%
# Create an empty RGB image
color_diff =         #TO DO

# %%
# Where images are equal → keep grayscale
mask_equal = img1 == img2
color_diff[mask_equal] =   # grayscale          #TO DO

# %%
# Where img1 > img2 → red
mask_red = img1 > img2
color_diff[mask_red] =          #TO DO

# Where img2 > img1 → blue
mask_blue = img2 > img1
color_diff[mask_blue] =         #TO DO

# %%
# Show result
plt.imshow(cv2.cvtColor(color_diff, cv2.COLOR_BGR2RGB))
plt.title("Gray + Differences in Red/Blue")
plt.axis('off')
plt.show()
